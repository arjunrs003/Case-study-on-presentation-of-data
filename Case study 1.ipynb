# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir('C:\\Users\\ss\\Documents\\Data Science Study material\\Data Science assignment')

# %%
#To read data
df=pd.read_csv('cars_data.csv')

# %%
df.head()
# Out:
#      Make    Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0  Suzuki   Vitara  Philippine     Female       Female         51
# 1   Honda    S2000      Henrik       Male         Male         30
# 2     BMW       Z4      Lebbie       Male       Female         54
# 3  Toyota   Tacoma    Jefferey     Female         Male         68
# 4    Ford  Festiva     Glendon     Female         Male         70
#
#         Buzzword   Country             City  Dealer Latitude  \
# 0  User-friendly   Belgium        Antwerpen        51.247239
# 1      analyzing     China            Jinhu        33.025433
# 2       software     China             Gemo        30.916207
# 3     monitoring  Portugal  Queluz de Baixo        38.745168
# 4       Sharable    Latvia         Jaunpils        56.729980
#
#    Dealer Longitude    Color  New Car Purchase Date  Sale Price  Discount  \
# 0          4.440346   Yellow    False    19/07/2009    54806.14    0.2467
# ...

# %%
#To check if there is any null value
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# No null values present in data

# %% [markdown]
# # Plot a bar graph of male vs female buyers participated in the sales.

# %%
plt.title('Male vs Female buyers participated in sales')
fig=df['Buyer Gender'].value_counts().plot(kind='bar', color=['red','brown'])
plt.xlabel('Gender')
plt.ylabel('Count of buyers')
plt.show()

# %%
sns.countplot(x='Buyer Gender', data=df)
# Out:
# <AxesSubplot:xlabel='Buyer Gender', ylabel='count'>

# %% [markdown]
# # Find the top 5 cars based on their sales price.

# %%
df_salesPrice_ascending=df.sort_values('Sale Price')

# %%
df_salesPrice_ascending.head()
# Out:
#          Make                 Model Nickname Car Gender Buyer Gender  \
# 3513      Geo               Tracker   Nowell       Male         Male
# 7234     Ford             Excursion   Patric       Male         Male
# 5956    Mazda                Mazda6   Milzie       Male       Female
# 6270   Nissan                 240SX   Paloma       Male       Female
# 6241  Lincoln  Continental Mark VII  Malissa     Female       Female
#
#       Buyer Age              Buzzword      Country        City  \
# 3513         64             impactful        Japan        Hagi
# 7234         30         Decentralized   Azerbaijan    Zaqatala
# 5956         39            motivating      Albania       Shezë
# 6270         48         Self-enabling  Philippines       Lanas
# 6241         57  budgetary management       Russia  Safakulevo
#
#       Dealer Latitude  Dealer Longitude      Color  New Car Purchase Date  \
# 3513        32.428624        130.649340     Orange     True    28/01/2016
# ...

# %% [markdown]
# The top 5 cars based on the sales price are Geo, Ford, Mazda, Nissan, Lincoin

# %% [markdown]
# # #Find the least 5 cars based on their Resell price.

# %%
df_ResellPrice_descending= df.sort_values('Resell Price', ascending=False)

# %%
df_ResellPrice_descending.tail()
# Out:
#             Make        Model Nickname Car Gender Buyer Gender  Buyer Age  \
# 5869    Infiniti          G37    Sonny       Male         Male         20
# 2538  Mitsubishi       3000GT     Thia     Female       Female         25
# 566       Jaguar           XF   Payton     Female         Male         64
# 4933         GMC  Savana 1500     Lark     Female       Female         34
# 2446   Chevrolet         1500  Corenda       Male       Female         25
#
#             Buzzword      Country              City  Dealer Latitude  \
# 5869      optimizing       France  Clermont-Ferrand        45.786764
# 2538  well-modulated        China        Yanweigang        34.509325
# 566        Visionary      Nigeria       Ikot-Ekpene         5.174447
# 4933     interactive       Poland       Śródmieście        53.838651
# 2446   collaboration  Philippines           Tubigan         8.490877
#
#       Dealer Longitude      Color  New Car Purchase Date  Sale Price  \
# ...

# %% [markdown]
# The least 5 cars based on resell price are Infiniti, Mitsubishi, Jaguar, GMC, Chevrolet
